# %%
from filtr import Filtr
import matplotlib.pyplot as plt
import numpy as np
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from skimage.io import imread

# %%
import os
from imageio import imread
Data_path = "D:\\Documents\\Atom\\myrepos\\Filtr\\Filtr\\Images"
Categories = ['Kick','Snare']
IMG_SIZE = 150
train = []

for category in Categories:
    path = os.path.join(Data_path,category)
    files = os.listdir(path)
    class_num = Categories.index(category)
    for img in files[2:5]:
        print(path)
        pic = os.path.join(path,img)
        print(pic)
        img_data = imread(pic)
        #img_data = cv2.resize(img_data,(IMG_SIZE,IMG_SIZE))
        #cv2.imshow('dat',img_data)
        print(img_data)
        plt.imshow(img_data,cmap = 'gray')
        plt.show()
        train.append([img_data,class_num])
# Out:
# D:\Documents\Atom\myrepos\Filtr\Filtr\Images\Kick
# D:\Documents\Atom\myrepos\Filtr\Filtr\Images\Kick\k_10.png
# [[[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  ...
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]]
# ...

# %%
img_data[0]
# Out:
# array([255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#        255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
# ...

# %%
len(train)
# Out:
# 20

# %%
for sample in train[:10]:
    print(sample[0])
# Out:
# [[[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  ...
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]]
# [[[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
# ...

# %%
import random
random.shuffle(train)

# %%
plt.imshow(train[0], cmap = 'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-628a4dc55565> in <module>
# ----> 1 plt.imshow(train[0], cmap = 'gray')
#       2 plt.show()
#
# D:\Documents\Anaconda\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
# -> 2677         None else {}), **kwargs)
#    2678     sci(__ret)
#    2679     return __ret
#
# D:\Documents\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# ...
